# %%
import torch

import os, json

# ROOT_PATH = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

annotation_path = "/Users/marcelloceresini/github/FSOD_CenterNet/data/fsod/annotations/fsod_train.json"
short_annotation_path = "/Users/marcelloceresini/github/FSOD_CenterNet/data/fsod/annotations/fsod_train_short.json"

with open(annotation_path, "r") as f:
    annotations = json.load(f)

# %%
print(annotations.keys())
print(annotations["categories"])
# Out:
# dict_keys(['images', 'type', 'annotations', 'categories'])
# ...

# %%
supercats = set()
cats = set()
for category in annotations["categories"]:
    supercats.add(category["supercategory"])
    cats.add(category["name"])

print(len(supercats))
print(len(cats))
# Out:
# 82
# 800

# %%
print(len(annotations["annotations"])/len(annotations["images"]))
# Out:
# 2.8173638968481374

# %%
im_id = set()
for a in annotations["annotations"]:
    if a["image_id"] in im_id:
        print("found duplicate", a)
        break
    else:
        im_id.add(a["image_id"])
# Out:
# found duplicate {'ignore': 0, 'image_id': 2019000000129, 'segmentation': 0, 'bbox': [379.0, 891.0, 66.0, 69.0], 'area': 0.0, 'category_id': 36, 'iscrowd': 0, 'id': 140}

# %%
for a in annotations["annotations"][120:140]:
    print(a)
# Out:
# {'ignore': 0, 'image_id': 2019000000121, 'segmentation': 0, 'bbox': [428.0, 562.0, 113.0, 115.0], 'area': 0.0, 'category_id': 65, 'iscrowd': 0, 'id': 121}
# {'ignore': 0, 'image_id': 2019000000122, 'segmentation': 0, 'bbox': [44.0, 78.0, 84.0, 74.0], 'area': 0.0, 'category_id': 112, 'iscrowd': 0, 'id': 122}
# {'ignore': 0, 'image_id': 2019000000123, 'segmentation': 0, 'bbox': [205.0, 216.0, 135.0, 363.0], 'area': 0.0, 'category_id': 11, 'iscrowd': 0, 'id': 123}
# {'ignore': 0, 'image_id': 2019000000124, 'segmentation': 0, 'bbox': [307.0, 0.0, 312.0, 584.0], 'area': 0.0, 'category_id': 113, 'iscrowd': 0, 'id': 124}
# {'ignore': 0, 'image_id': 2019000000125, 'segmentation': 0, 'bbox': [241.0, 207.0, 154.0, 124.0], 'area': 0.0, 'category_id': 114, 'iscrowd': 0, 'id': 125}
# {'ignore': 0, 'image_id': 2019000000126, 'segmentation': 0, 'bbox': [176.0, 148.0, 558.0, 47.0], 'area': 0.0, 'category_id': 115, 'iscrowd': 0, 'id': 126}
# ...

# %%
for a in annotations["images"][124:130]:
    print(a)
# Out:
# {'id': 2019000000125, 'file_name': 'part_1/n04599235/n04599235_25999.jpg', 'width': 500, 'height': 333}
# {'id': 2019000000126, 'file_name': 'part_2/train_part_0/06/067b21967e181c48.jpg', 'width': 1024, 'height': 768}
# {'id': 2019000000127, 'file_name': 'part_1/n09835506/n09835506_3579.jpg', 'width': 500, 'height': 375}
# {'id': 2019000000128, 'file_name': 'part_2/train_part_2/24/24cafc5df35632d9.jpg', 'width': 1024, 'height': 768}
# {'id': 2019000000129, 'file_name': 'part_2/train_part_9/90/907d72176b009b11.jpg', 'width': 729, 'height': 1024}
# {'id': 2019000000130, 'file_name': 'part_2/train_part_6/66/66735d91684b33a1.jpg', 'width': 1024, 'height': 768}

# %%
print(annotations["images"][0])
# Out:
# {'id': 2019000000000, 'file_name': 'part_2/train_part_e/e8/e8fe15d38a65c26b.jpg', 'width': 1024, 'height': 719}

# %%
annotations_short = annotations.copy()
annotations_short["images"] = annotations_short["images"][124:130]

# %%
with open(short_annotation_path, "w") as f:
    json.dump(annotations_short, f)
